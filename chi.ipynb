# %%
import pandas as pd

df = pd.read_csv('chi.csv').set_index('track')
df_sort = df.sort_values(by=['chi/len', 'len_track'], ascending=False)
df_sort.head(10)
# Out:
#              chi  len_track    chi/len
# track
# 185    125.47470          6  20.912450
# 1314    99.00820          5  19.801640
# 1305    98.93740          5  19.787480
# 6402    58.36410          3  19.454700
# 3309    71.67300          4  17.918250
# 9862    53.04160          3  17.680533
# 4237    70.17680          4  17.544200
# 10483  139.86482          8  17.483103
# 5228    69.85450          4  17.463625
# 222     69.28680          4  17.321700

# %%
df.sort_values(by=['len_track'], ascending=False).head(10)
# Out:
#               chi  len_track   chi/len
# track
# 8962   105.853324         53  1.997233
# 4330   350.062297         53  6.604949
# 4110   160.533224         53  3.028929
# 5509   125.336683         53  2.364843
# 8961    82.615980         52  1.588769
# 5354   146.916547         52  2.825318
# 1298   227.658454         52  4.378047
# 4343   208.488105         52  4.009387
# 4344   215.385739         52  4.142033
# 4356   287.680002         52  5.532308

# %%
df = pd.DataFrame()
df['chi/len'] = df_sort['chi/len'].values
df.plot()
# Out:
# <Axes: >

# %%
df.sort_values(by=['chi/len', 'len_track'], ascending=True).head(10)
# Out:
#                 chi  len_track       chi/len
# track
# 8451   3.635740e-13          1  3.635740e-13
# 8450   1.222530e-11          1  1.222530e-11
# 8367   2.964660e-11          1  2.964660e-11
# 5100   4.440540e-11          1  4.440540e-11
# 7852   1.128400e-10          1  1.128400e-10
# 5258   4.102280e-10          1  4.102280e-10
# 2363   1.197970e-03          3  3.993234e-04
# 7515   4.630261e-03          3  1.543420e-03
# 10077  1.104689e-02          3  3.682295e-03
# 4710   1.183520e-02          2  5.917601e-03
